# %%
import pandas as pd

# %%
statistics=pd.read_csv('../../output/statistics.csv')

# %%
statistics=statistics.iloc[:,1:]

# %%
statistics
# Out:
#   MODEL_TYPE       MAE       MSE      RMSE        R²
# 0         RF  0.025703  0.000917  0.030290  0.788077
# 1       LSTM  0.015664  0.000333  0.018245  0.923112

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(24,8))
plt.subplot(141)
plt.title('MAE')
plt.bar(statistics.MODEL_TYPE,statistics.MAE)
plt.subplot(142)
plt.title('MSE')
plt.bar(statistics.MODEL_TYPE,statistics.MSE)
plt.subplot(143)
plt.title('RMSE')
plt.bar(statistics.MODEL_TYPE,statistics.RMSE)
plt.subplot(144)
plt.title('R²')
plt.bar(statistics.MODEL_TYPE,statistics['R²'])
plt.show()
